# %% [markdown]
# # GROOT Basic Application

# %% [markdown]
# ## Data Gathering

# %%
import requests
from bs4 import BeautifulSoup
import pickle #save data

# Scrapes the threat report from https://www.us-cert.gov/ncas/alerts/
def url_to_report(url):
    '''Return threat report specifically from https://www.us-cert.gov/ncas/alerts/ '''
    page = requests.get(url).text
    soup = BeautifulSoup(page, "lxml") #html parsing
    text = [p.text for p in soup.find(class_="region region-content").find_all(["h1","h2","h3", "h4","p","ul","table"])] 
    #search through the CISA webpage for the region region-content section (i.e. which contains the entirety of the threat report) 
    #and select the paragraphs, headers, list, etc.
    print(url)
    return text

# URL of the threat report that we want to analyze
urls = ['https://www.us-cert.gov/ncas/alerts/TA17-163A']

# Let's create an array of the number of threat reports  
number = ['1']

# %%
#Actually requests the threat reports from the CISA's webpage(s)
reports = [url_to_report(u) for u in urls]
# Out:
# https://www.us-cert.gov/ncas/alerts/TA17-163A

# %%
#Make a new directory to hold the text files
# !mkdir reports

for i, n in enumerate(number):
    with open("reports/" + n + ".txt", "wb") as file:
        pickle.dump(reports[i], file)
# Out:
# mkdir: reports: File exists

# %%
#Load pickled files
data = {}
for i, n in enumerate(number):
    with open("reports/" + n + ".txt", "rb") as file:
        data[n] = pickle.load(file)

# %%
#Double check to make sure the data has been loaded properly
#data.keys()

# %%
#Checking (again) this time to the see the data's content
#data['1'][:99]

# %%
#Let's take a look at the data again
#next(iter(data.keys()))

# %%
#Notice that our dictionary is currently in key: number, value: text from report
#next(iter(data.values()))

# %%
def combine_text(list_of_text):
    '''Takes a list of text and combines them into one large chunk of text.'''
    combined_text = ' '.join(list_of_text)
    return combined_text

# %%
# Combine it!
data_combined = {key: [combine_text(value)] for (key,value) in data.items()}

# %%
#Creating the database using the pandas library
import pandas as pd
pd.set_option('max_colwidth', 150)

data_df = pd.DataFrame.from_dict(data_combined).transpose()
data_df.columns = ['reports']
data_df = data_df.sort_index()
data_df
# Out:
#                                                                                                                                                  reports
# 1  Alert (TA17-163A) CrashOverride Malware Systems Affected Industrial Control Systems Overview The National Cybersecurity and Communications Integra...

# %%
data_df.reports.loc['1'] #View the entirety of the data scraped from the threat report (i.e stored in the database)
# Out:
# 'Alert (TA17-163A) CrashOverride Malware Systems Affected Industrial Control Systems Overview The National Cybersecurity and Communications Integration Center (NCCIC) is aware of public reports from ESET and Dragos outlining a new, highly capable Industrial Controls Systems (ICS) attack platform that was reportedly used in 2016 against critical infrastructure in Ukraine. As reported by ESET and Dragos, the CrashOverride malware is an extensible platform that could be used to target critical infrastructure sectors. NCCIC is working with its partners to validate the ESET and Dragos analysis, and develop a better understanding of the risk this new malware poses to U.S. critical infrastructure. Although this activity is still under investigation, NCCIC is sharing this report to provide organizations with detection and mitigation recommendations to help prevent future compromises within their critical infrastructure networks. NCCIC continues to work with interagency and international partners on this activity and will provide updates as information becomes available. For a downloadable copy of indicators of compromise (IOCs), see: IOCs (.csv)IOCs (.stix) To report activity related to this Alert, please contact NCCIC at NCCICCustomerService@hq.dhs.gov or 1-888-282-0870. Risk Evaluation NCCIC Cyber Incident Scoring System (NCISS) Rating Priority Level (Color)Yellow (Medium)A medium priority incident may affect public health or safety, national security, economic security, foreign relations, civil liberties, or public confidence. Details There is no evidence to suggest this malware has affected U.S. critical infrastructure. However, the tactics, techniques, and procedures (TTPs) described as part of the CrashOverride malware could be modified to target U.S. critical information networks and systems. Description Technical Analysis CrashOverride malware represents a scalable, capable platform. The modules and capabilities publically reported appear to focus on organizations using ICS protocols IEC101, IEC104, and IEC61850, which are more commonly used outside the United States in electric power control systems. The platform fundamentally abuses the functionality of a targeted ICS system’s legitimate control system to achieve its intended effect. While the known capabilities do not appear to be U.S.-focused, it is important to recognize that the general TTPs used in CrashOverride could be leveraged with modified technical implementations to affect U.S.-based critical infrastructure. With further modification, CrashOverride or similar malware could have implications beyond electric power so all critical infrastructure organizations should be evaluating their systems to susceptibilities in the TTPs outlined. The malware has several reported capabilities: Detection As CrashOverride is a second stage malware capability and has the ability to operate independent of initial C2, traditional methods of detection may not be sufficient to detect infections prior to the malware executing. As a result, organizations are encouraged to implement behavioral analysis techniques to attempt to identify precursor activity to CrashOverride. As additional information becomes available on stage one infection vectors and TTPs, this alert will be updated. NCCIC is providing a compilation of IOCs (see links above) from a variety of sources to aid in the detection of this malware. The sources provided do not constitute an exhaustive list and the U.S. Government does not endorse or support any particular product or vendor’s information referenced in this report. However, NCCIC has included this data to ensure wide distribution of the most comprehensive information available and will provide updates as warranted. import “pe”import “hash” rule dragos_crashoverride_exporting_dlls{meta:description = “CRASHOVERRIDE v1 Suspicious Export”author = “Dragos Inc”condition:pe.exports(“Crash”) & pe.characteristics} rule dragos_crashoverride_suspcious{meta:description = “CRASHO ...

# %% [markdown]
# ### Manual Extraction

# %%
#This command searchs for the existence of email addresses in the dataset
data_df.reports.str.findall('[A-Za-z0-9_]+@[A-Za-z0-9_]+(?:.dhs.gov|.gov|.com)')
# Out:
# 1    [NCCICCustomerService@hq.dhs.gov]
# Name: reports, dtype: object

# %%
#This line should extract all of the file extensions within the report
data_df.reports.str.findall('[A-Za-z0-9_]*(?:.dll|.exe)+')
# Out:
# 1    [malware exe, dragos_crashoverride_exporting_dll, 101.dll, Crash101.dll, 104.dll, Crash104.dll, 61850.dll, Crash61850.dll, OPCClientDemo.dll, Cras...
# Name: reports, dtype: object

# %% [markdown]
# ## Data Cleaning

# %%
import re
import string 

def clean_text_round1(text):
   '''Make text lowercase, remove text in square brackets, remove punctuation, and remove words with numbers''' 
   text = text.lower() #transform text to lowercase; we can add additional functions to further clean the data later on if necessary
   #text = re.sub('\[.*?\]','', text) #remove punctuation
   text = re.sub('[%s]'% re.escape(string.punctuation),'',text)
   text = re.sub('\w*\d\w*','', text) #remove text with numbers
   return text

round1 = lambda x: clean_text_round1(x)

# %%
#Let's take a look at the updated text
data_clean = pd.DataFrame(data_df.reports.apply(round1))
data_clean
# Out:
#                                                                                                                                                  reports
# 1  alert  crashoverride malware systems affected industrial control systems overview the national cybersecurity and communications integration center...

# %%
# Apply a second round of cleaning
def clean_text_round2(text):
    '''Get rid of some additional punctuation and non-sensical text that was missed the first time around.'''
    text = re.sub('[‘’“”…]', '', text)
    #text = re.sub('\n', '', text)
    return text

round2 = lambda x: clean_text_round2(x)

# %%
#Let's take a look at the updated text
data_clean = pd.DataFrame(data_clean.reports.apply(round2))
data_clean
# Out:
#                                                                                                                                                  reports
# 1  alert  crashoverride malware systems affected industrial control systems overview the national cybersecurity and communications integration center...

# %%
#Let's pickle the file for later use
data_clean.to_pickle("corpus.pkl")

# %% [markdown]
# ## Entity and Relationship Extraction

# %% [markdown]
# Using regular expressions and following the Applied Text Mining Coursea course, we were able to extract an email address, hash, and file extensions

# %% [markdown]
# ### Natural Language Toolkit (NLTK)

# %% [markdown]
# Using the NLTK, we attempted to extract entities as well as their relationships from the threat reports. Before applying this process we may want to remove

# %%
import nltk
from nltk.tokenize import word_tokenize

tokenize = word_tokenize(data_clean.reports.loc['1'])
tokenize
# Out:
# ['alert',
#  'crashoverride',
#  'malware',
#  'systems',
#  'affected',
#  'industrial',
#  'control',
#  'systems',
#  'overview',
#  'the',
#  'national',
#  'cybersecurity',
#  'and',
#  'communications',
#  'integration',
#  'center',
#  'nccic',
#  'is',
#  'aware',
#  'of',
#  'public',
#  'reports',
#  'from',
#  'eset',
#  'and',
#  'dragos',
#  'outlining',
#  'a',
#  'new',
#  'highly',
#  'capable',
#  'industrial',
#  'controls',
#  'systems',
#  'ics',
#  'attack',
#  'platform',
#  'that',
#  'was',
#  'reportedly',
#  'used',
#  'in',
#  'against',
#  'critical',
#  'infrastructure',
#  'in',
#  'ukraine',
#  'as',
#  'reported',
#  'by',
#  'eset',
#  'and',
#  'dragos',
#  'the',
#  'crashoverride',
#  'malware',
#  'is',
#  'an',
#  'extensible',
#  'platform',
#  'that',
#  'could',
#  'be',
#  'used',
#  'to',
#  'target',
#  'critical',
#  'infrastructure',
#  'sectors',
#  'nccic',
#  'is',
#  'working',
#  'with',
#  'its',
#  'partners',
#  'to',
#  'validate',
#  'the',
#  'eset',
#  'and',
#  'dragos',
#  'analysis',
#  'and',
#  'develop',
#  'a',
#  'better',
#  'understanding',
#  'of',
#  'the',
#  'risk',
#  'this',
#  'new',
#  'malware',
#  'poses',
#  'to',
#  'us',
#  'critical',
#  'infrastructure',
#  'although',
#  'this',
#  'activity',
#  'is',
#  'still',
#  'under',
#  'investigation',
#  'nccic',
#  'is',
#  'sharing',
#  'this',
#  'report',
#  'to',
#  'provide',
#  'organizations',
#  'with',
#  'detection',
#  'and',
#  'mitigation',
#  'recommendations',
#  'to',
#  'help',
#  'prevent',
#  'future',
#  'compromises',
#  'within',
#  'their',
#  'critical',
#  'infrastructure',
#  'networks',
#  'nccic',
#  'continues',
#  'to',
#  'work',
#  'with',
#  'interagency',
#  'and',
#  'international',
#  'partners',
#  'on',
#  'this',
#  'activity',
#  'and',
#  'will',
#  'provide',
#  'updates',
#  'as',
#  'information',
#  'becomes',
#  'available',
#  'for',
#  'a',
#  'downloadable',
#  'copy',
#  'of',
#  'indicators',
#  'of',
#  'compromise',
#  'iocs',
#  'see',
#  'iocs',
#  'csviocs',
#  'stix',
#  'to',
#  'report',
#  'activity',
#  'related',
#  'to',
#  'this',
#  'alert',
#  'please',
#  'contact',
#  'nccic',
#  'at',
#  'ncciccustomerservicehqdhsgov',
#  'or',
#  'risk',
#  'evaluation',
#  'nccic',
#  'cyber',
#  'incident',
#  'scoring',
#  'system',
#  'nciss',
#  'rating',
#  'priority',
#  'level',
#  'coloryellow',
#  'mediuma',
#  'medium',
#  'priority',
#  'incident',
#  'may',
#  'affect',
#  'public',
#  'health',
#  'or',
#  'safety',
#  'national',
#  'security',
#  'economic',
#  'security',
#  'foreign',
#  'relations',
#  'civil',
#  'liberties',
#  'or',
#  'public',
#  'confidence',
#  'details',
#  'there',
#  'is',
#  'no',
#  'evidence',
#  'to',
#  'suggest',
#  'this',
#  'malware',
#  'has',
#  'affected',
#  'us',
#  'critical',
#  'infrastructure',
#  'however',
#  'the',
#  'tactics',
#  'techniques',
#  'and',
#  'procedures',
#  'ttps',
#  'described',
#  'as',
#  'part',
#  'of',
#  'the',
#  'crashoverride',
#  'malware',
#  'could',
#  'be',
#  'modified',
#  'to',
#  'target',
#  'us',
#  'critical',
#  'information',
#  'networks',
#  'and',
#  'systems',
#  'description',
#  'technical',
#  'analysis',
#  'crashoverride',
#  'malware',
#  'represents',
#  'a',
#  'scalable',
#  'capable',
#  'platform',
#  'the',
#  'modules',
#  'and',
#  'capabilities',
#  'publically',
#  'reported',
#  'appear',
#  'to',
#  'focus',
#  'on',
#  'organizations',
#  'using',
#  'ics',
#  'protocols',
#  'and',
#  'which',
#  'are',
#  'more',
#  'commonly',
#  'used',
#  'outside',
#  'the',
#  'united',
#  'states',
#  'in',
#  'electric',
#  'power',
#  'control',
#  'systems',
#  'the',
#  'platform',
#  'fundamentally',
#  'abuses',
#  'the',
#  'functionality',
#  'of',
#  'a',
#  'targeted',
#  'ics',
#  'systems',
#  'legitimate',
#  'control',
#  'system',
#  'to',
#  'achieve',
#  'its',
#  'intended',
#  'effect',
#  'while',
#  'the',
#  'known',
#  'capabilities',
#  'do',
#  'not',
#  'appear',
#  'to',
#  'be',
#  'usfocused',
#  'it',
#  'is',
#  'important',
#  'to',
#  'recognize',
#  'that',
#  'the',
#  'general',
#  'ttps',
#  'used',
#  'in',
#  'crashoverride',
#  'could',
#  'be',
#  'leveraged',
#  'with',
#  'modified',
#  'technical',
#  'implementations',
#  'to',
#  'affect',
#  'usbased',
#  'critical',
#  'infrastructure',
#  'with',
#  'further',
#  'modification',
#  'crashoverride',
#  'or',
#  'similar',
#  'malware',
#  'could',
#  'have',
#  'implications',
#  'beyond',
#  'electric',
#  'power',
#  'so',
#  'all',
#  'critical',
#  'infrastructure',
#  'organizations',
#  'should',
#  'be',
#  'evaluating',
#  'their',
#  'systems',
#  'to',
#  'susceptibilities',
#  'in',
#  'the',
#  'ttps',
#  'outlined',
#  'the',
#  'malware',
#  'has',
#  'several',
#  'reported',
#  'capabilities',
#  'detection',
#  'as',
#  'crashoverride',
#  'is',
#  'a',
#  'second',
#  'stage',
#  'malware',
#  'capability',
#  'and',
#  'has',
#  'the',
#  'ability',
#  'to',
#  'operate',
#  'independent',
#  'of',
#  'initial',
#  'traditional',
#  'methods',
#  'of',
#  'detection',
#  'may',
#  'not',
#  'be',
#  'sufficient',
#  'to',
#  'detect',
#  'infections',
#  'prior',
#  'to',
#  'the',
#  'malware',
#  'executing',
#  'as',
#  'a',
#  'result',
#  'organizations',
#  'are',
#  'encouraged',
#  'to',
#  'implement',
#  'behavioral',
#  'analysis',
#  'techniques',
#  'to',
#  'attempt',
#  'to',
#  'identify',
#  'precursor',
#  'activity',
#  'to',
#  'crashoverride',
#  'as',
#  'additional',
#  'information',
#  'becomes',
#  'available',
#  'on',
#  'stage',
#  'one',
#  'infection',
#  'vectors',
#  'and',
#  'ttps',
#  'this',
#  'alert',
#  'will',
#  'be',
#  'updated',
#  'nccic',
#  'is',
#  'providing',
#  'a',
#  'compilation',
#  'of',
#  'iocs',
#  'see',
#  'links',
#  'above',
#  'from',
#  'a',
#  'variety',
#  'of',
#  'sources',
#  'to',
#  'aid',
#  'in',
#  'the',
#  'detection',
#  'of',
#  'this',
#  'malware',
#  'the',
#  'sources',
#  'provided',
#  'do',
#  'not',
#  'constitute',
#  'an',
#  'exhaustive',
#  'list',
#  'and',
#  'the',
#  'us',
#  'government',
#  'does',
#  'not',
#  'endorse',
#  'or',
#  'support',
#  'any',
#  'particular',
#  'product',
#  'or',
#  'vendors',
#  'information',
#  'referenced',
#  'in',
#  'this',
#  'report',
#  'however',
#  'nccic',
#  'has',
#  'included',
#  'this',
#  'data',
#  'to',
#  'ensure',
#  'wide',
#  'distribution',
#  'of',
#  'the',
#  'most',
#  'comprehensive',
#  'information',
#  'available',
#  'and',
#  'will',
#  'provide',
#  'updates',
#  'as',
#  'warranted',
#  'import',
#  'peimport',
#  'hash',
#  'rule',
#  'dragoscrashoverrideexportingdllsmetadescription',
#  'crashoverride',
#  'suspicious',
#  'exportauthor',
#  'dragos',
#  'incconditionpeexportscrash',
#  'pecharacteristics',
#  'rule',
#  'dragoscrashoverridesuspciousmetadescription',
#  'crashoverride',
#  'wiperauthor',
#  'dragos',
#  'inc',
#  'sysbasconcom',
#  'fullword',
#  'nocase',
#  'pcmp',
#  'fullword',
#  'nocase',
#  'pcmi',
#  'fullword',
#  'nocase',
#  'pcmt',
#  'fullword',
#  'nocase',
#  'cin',
#  'fullword',
#  'nocase',
#  'wideconditionpeexportscrash',
#  'and',
#  'any',
#  'of',
#  's',
#  'rule',
#  'dragoscrashoverridenamesearch',
#  'metadescription',
#  'crashoverride',
#  'suspicious',
#  'strings',
#  'and',
#  'exportauthor',
#  'dragos',
#  'inc',
#  'fullword',
#  'nocase',
#  'fullword',
#  'nocase',
#  'fullword',
#  'nocase',
#  'fullword',
#  'nocase',
#  'fullword',
#  'nocase',
#  'fullword',
#  'nocase',
#  'opcclientdemodll',
#  'fullword',
#  'nocase',
#  'opc',
#  'fullword',
#  'nocase',
#  'crashopcclientdemodll',
#  'fullword',
#  'nocase',
#  'fullword',
#  'nocase',
#  'fullword',
#  'nocase',
#  'fullword',
#  'nocase',
#  'opcexe',
#  'fullword',
#  'nocase',
#  'hasloexe',
#  'fullword',
#  'nocase',
#  'haslodat',
#  'fullword',
#  'nocase',
#  'wideconditionany',
#  'of',
#  's',
#  'and',
#  'peexportscrash',
#  'rule',
#  'dragoscrashoverridehashes',
#  'metadescription',
#  'crashoverride',
#  'malware',
#  'hashesauthor',
#  'dragos',
#  'inc',
#  'conditionfilesize',
#  'filesize',
#  'filesize',
#  'filesize',
#  'filesize',
#  'filesize',
#  'filesize',
#  'filesize',
#  'filesize',
#  'filesize',
#  'rule',
#  'dragoscrashoverridemodulestrings',
#  'metadescription',
#  'interaction',
#  'module',
#  'program',
#  'stringsauthor',
#  'dragos',
#  'inc',
#  'client',
#  'ips',
#  'ports',
#  'asduu',
#  'nocase',
#  'wide',
#  'mstr',
#  'slv',
#  'nocase',
#  'wide',
#  'mstr',
#  'slv',
#  'nocase',
#  'wide',
#  'unknown',
#  'apdu',
#  'format',
#  'nocase',
#  'wide',
#  'nocase',
#  'wide',
#  'asciiconditionany',
#  'of',
#  's',
#  'rule',
#  'dragoscrashoverrideconfigreadermetadescription',
#  'crashoverride',
#  'config',
#  'file',
#  'parsingauthor',
#  'dragos',
#  'inc',
#  'eb',
#  'cf',
#  'conditionall',
#  'of',
#  'them',
#  'rule',
#  'dragoscrashoverrideconfigreadermetadescription',
#  'crashoverride',
#  'config',
#  'file',
#  'parsingauthor',
#  'dragos',
#  'inc',
#  'eb',
#  'cf',
#  'conditionall',
#  'of',
#  'them',
#  'rule',
#  'dragoscrashoverrideweirdmutexmetadescription',
#  'blank',
#  'mutex',
#  'creation',
#  'assoicated',
#  'with',
#  'crashoverrideauthor',
#  'dragos',
#  'inc',
#  'ec',
#  'ff',
#  'ff',
#  'ff',
#  'ff',
#  'of',
#  'them',
#  'rule',
#  'dragoscrashoverrideservicestompermetadescription',
#  'identify',
#  'service',
#  'hollowing',
#  'and',
#  'persistence',
#  'settingauthor',
#  'dragos',
#  'inc',
#  'ff',
#  'ff',
#  'ff',
#  'ff',
#  'ff',
#  'ff',
#  'conditionall',
#  'of',
#  'them',
#  'rule',
#  'dragoscrashoverridewipermoduleregistrymetadescription',
#  'registry',
#  'wiper',
#  'functionality',
#  'assoicated',
#  'with',
#  'crashoverrideauthor',
#  'dragos',
#  'inc',
#  'ff',
#  'ff',
#  'ff',
#  'ff',
#  'conditionall',
#  'of',
#  'them',
#  'rule',
#  'dragoscrashoverridewiperfilemanipulationmetadescription',
#  'file',
#  'manipulation',
#  'actions',
#  'associated',
#  'with',
#  'crashoverride',
#  'wip¬erauthor',
#  'dragos',
#  'inc',
#  'ff',
#  'ff',
#  'conditionall',
#  'of',
#  'them',
#  'impact',
#  'a',
#  'successful',
#  'network',
#  'intrusion',
#  'can',
#  'have',
#  'severe',
#  'impacts',
#  'particularly',
#  'if',
#  'the',
#  'compromise',
#  'becomes',
#  'public',
#  'and',
#  'sensitive',
#  'information',
#  'is',
#  'exposed',
#  'possible',
#  'impacts',
#  'include',
#  'temporary',
#  'or',
#  'permanent',
#  'loss',
#  'of',
#  'sensitive',
#  'or',
#  'proprietary',
#  'informationdisruption',
#  'to',
#  'regular',
#  'operationsfinancial',
#  'losses',
#  'incurred',
#  'to',
#  'restore',
#  'systems',
#  'and',
#  'files',
#  'andpotential',
#  'harm',
#  'to',
#  'an',
#  'organizations',
#  'reputation',
#  'solution',
#  'properly',
#  'implemented',
#  'defensive',
#  'techniques',
#  'and',
#  'common',
#  'cyber',
#  'hygiene',
#  'practices',
#  'increase',
#  'the',
#  'complexity',
#  'of',
#  'barriers',
#  'that',
#  'adversaries',
#  'must',
#  'overcome',
#  'to',
#  'gain',
#  'unauthorized',
#  'access',
#  'to',
#  'critical',
#  'information',
#  'networks',
#  'and',
#  'systems',
#  'in',
#  'addition',
#  'detection',
#  'and',
#  'prevention',
#  'mechanisms',
#  'can',
#  'expose',
#  'malicious',
#  'network',
#  'activity',
#  'enabling',
#  'organizations',
#  'to',
#  'contain',
#  'and',
#  'respond',
#  'to',
#  'intrusions',
#  'more',
#  'rapidly',
#  'there',
#  'is',
#  'no',
#  'set',
#  'of',
#  'defensive',
#  'techniques',
#  'or',
#  'programs',
#  'that',
#  'will',
#  'completely',
#  'avert',
#  'all',
#  'attacks',
#  'however',
#  'layered',
#  'cybersecurity',
#  'defenses',
#  'will',
#  'aid',
#  'in',
#  'reducing',
#  'an',
#  'organizations',
#  'attack',
#  'surface',
#  'and',
#  'will',
#  'increase',
#  'the',
#  'likelihood',
#  'of',
#  'detection',
#  'this',
#  'layered',
#  'mitigation',
#  'approach',
#  'is',
#  'known',
#  'as',
#  'defenseindepthnccic',
#  'has',
#  'based',
#  'its',
#  'mitigations',
#  'and',
#  'recommendations',
#  'on',
#  'its',
#  'analysis',
#  'of',
#  'the',
#  'public',
#  'reporting',
#  'of',
#  'this',
#  'malware',
#  'and',
#  'will',
#  'be',
#  'provide',
#  'updates',
#  'as',
#  'more',
#  'information',
#  'becomes',
#  'availablecritical',
#  'infrastructure',
#  'companies',
#  'should',
#  'ensure',
#  'that',
#  'they',
#  'are',
#  'following',
#  'best',
#  'practices',
#  'which',
#  'are',
#  'outlined',
#  'in',
#  'the',
#  'seven',
#  'steps',
#  'to',
#  'effectively',
#  'defend',
#  'industrial',
#  'control',
#  'systems',
#  'document',
#  'produced',
#  'jointly',
#  'by',
#  'dhs',
#  'nsa',
#  'and',
#  'fbi',
#  'application',
#  'whitelisting',
#  'application',
#  'whitelisting',
#  'awl',
#  'can',
#  'detect',
#  'and',
#  'prevent',
#  'attempted',
#  'execution',
#  'of',
#  'malware',
#  'uploaded',
#  'by',
#  'adversaries',
#  'application',
#  'whitelisting',
#  'hardens',
#  'operating',
#  'systems',
#  'and',
#  'prevents',
#  'the',
#  'execution',
#  'of',
#  'unauthorized',
#  'software',
#  'the',
#  'static',
#  'nature',
#  'of',
#  'some',
#  'systems',
#  'such',
#  'as',
#  'database',
#  'servers',
#  'and',
#  'humanmachine',
#  'interface',
#  'hmi',
#  'computers',
#  'make',
#  'these',
#  'ideal',
#  'candidates',
#  'to',
#  'run',
#  'awl',
#  'nccic',
#  'encourages',
#  'operators',
#  ...]

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english')) #stop words in the english language
#stop_words

#remove stop words
filtered = [w for w in tokenize if not w in stop_words]
filtered
# Out:
# ['alert',
#  'crashoverride',
#  'malware',
#  'systems',
#  'affected',
#  'industrial',
#  'control',
#  'systems',
#  'overview',
#  'national',
#  'cybersecurity',
#  'communications',
#  'integration',
#  'center',
#  'nccic',
#  'aware',
#  'public',
#  'reports',
#  'eset',
#  'dragos',
#  'outlining',
#  'new',
#  'highly',
#  'capable',
#  'industrial',
#  'controls',
#  'systems',
#  'ics',
#  'attack',
#  'platform',
#  'reportedly',
#  'used',
#  'critical',
#  'infrastructure',
#  'ukraine',
#  'reported',
#  'eset',
#  'dragos',
#  'crashoverride',
#  'malware',
#  'extensible',
#  'platform',
#  'could',
#  'used',
#  'target',
#  'critical',
#  'infrastructure',
#  'sectors',
#  'nccic',
#  'working',
#  'partners',
#  'validate',
#  'eset',
#  'dragos',
#  'analysis',
#  'develop',
#  'better',
#  'understanding',
#  'risk',
#  'new',
#  'malware',
#  'poses',
#  'us',
#  'critical',
#  'infrastructure',
#  'although',
#  'activity',
#  'still',
#  'investigation',
#  'nccic',
#  'sharing',
#  'report',
#  'provide',
#  'organizations',
#  'detection',
#  'mitigation',
#  'recommendations',
#  'help',
#  'prevent',
#  'future',
#  'compromises',
#  'within',
#  'critical',
#  'infrastructure',
#  'networks',
#  'nccic',
#  'continues',
#  'work',
#  'interagency',
#  'international',
#  'partners',
#  'activity',
#  'provide',
#  'updates',
#  'information',
#  'becomes',
#  'available',
#  'downloadable',
#  'copy',
#  'indicators',
#  'compromise',
#  'iocs',
#  'see',
#  'iocs',
#  'csviocs',
#  'stix',
#  'report',
#  'activity',
#  'related',
#  'alert',
#  'please',
#  'contact',
#  'nccic',
#  'ncciccustomerservicehqdhsgov',
#  'risk',
#  'evaluation',
#  'nccic',
#  'cyber',
#  'incident',
#  'scoring',
#  'system',
#  'nciss',
#  'rating',
#  'priority',
#  'level',
#  'coloryellow',
#  'mediuma',
#  'medium',
#  'priority',
#  'incident',
#  'may',
#  'affect',
#  'public',
#  'health',
#  'safety',
#  'national',
#  'security',
#  'economic',
#  'security',
#  'foreign',
#  'relations',
#  'civil',
#  'liberties',
#  'public',
#  'confidence',
#  'details',
#  'evidence',
#  'suggest',
#  'malware',
#  'affected',
#  'us',
#  'critical',
#  'infrastructure',
#  'however',
#  'tactics',
#  'techniques',
#  'procedures',
#  'ttps',
#  'described',
#  'part',
#  'crashoverride',
#  'malware',
#  'could',
#  'modified',
#  'target',
#  'us',
#  'critical',
#  'information',
#  'networks',
#  'systems',
#  'description',
#  'technical',
#  'analysis',
#  'crashoverride',
#  'malware',
#  'represents',
#  'scalable',
#  'capable',
#  'platform',
#  'modules',
#  'capabilities',
#  'publically',
#  'reported',
#  'appear',
#  'focus',
#  'organizations',
#  'using',
#  'ics',
#  'protocols',
#  'commonly',
#  'used',
#  'outside',
#  'united',
#  'states',
#  'electric',
#  'power',
#  'control',
#  'systems',
#  'platform',
#  'fundamentally',
#  'abuses',
#  'functionality',
#  'targeted',
#  'ics',
#  'systems',
#  'legitimate',
#  'control',
#  'system',
#  'achieve',
#  'intended',
#  'effect',
#  'known',
#  'capabilities',
#  'appear',
#  'usfocused',
#  'important',
#  'recognize',
#  'general',
#  'ttps',
#  'used',
#  'crashoverride',
#  'could',
#  'leveraged',
#  'modified',
#  'technical',
#  'implementations',
#  'affect',
#  'usbased',
#  'critical',
#  'infrastructure',
#  'modification',
#  'crashoverride',
#  'similar',
#  'malware',
#  'could',
#  'implications',
#  'beyond',
#  'electric',
#  'power',
#  'critical',
#  'infrastructure',
#  'organizations',
#  'evaluating',
#  'systems',
#  'susceptibilities',
#  'ttps',
#  'outlined',
#  'malware',
#  'several',
#  'reported',
#  'capabilities',
#  'detection',
#  'crashoverride',
#  'second',
#  'stage',
#  'malware',
#  'capability',
#  'ability',
#  'operate',
#  'independent',
#  'initial',
#  'traditional',
#  'methods',
#  'detection',
#  'may',
#  'sufficient',
#  'detect',
#  'infections',
#  'prior',
#  'malware',
#  'executing',
#  'result',
#  'organizations',
#  'encouraged',
#  'implement',
#  'behavioral',
#  'analysis',
#  'techniques',
#  'attempt',
#  'identify',
#  'precursor',
#  'activity',
#  'crashoverride',
#  'additional',
#  'information',
#  'becomes',
#  'available',
#  'stage',
#  'one',
#  'infection',
#  'vectors',
#  'ttps',
#  'alert',
#  'updated',
#  'nccic',
#  'providing',
#  'compilation',
#  'iocs',
#  'see',
#  'links',
#  'variety',
#  'sources',
#  'aid',
#  'detection',
#  'malware',
#  'sources',
#  'provided',
#  'constitute',
#  'exhaustive',
#  'list',
#  'us',
#  'government',
#  'endorse',
#  'support',
#  'particular',
#  'product',
#  'vendors',
#  'information',
#  'referenced',
#  'report',
#  'however',
#  'nccic',
#  'included',
#  'data',
#  'ensure',
#  'wide',
#  'distribution',
#  'comprehensive',
#  'information',
#  'available',
#  'provide',
#  'updates',
#  'warranted',
#  'import',
#  'peimport',
#  'hash',
#  'rule',
#  'dragoscrashoverrideexportingdllsmetadescription',
#  'crashoverride',
#  'suspicious',
#  'exportauthor',
#  'dragos',
#  'incconditionpeexportscrash',
#  'pecharacteristics',
#  'rule',
#  'dragoscrashoverridesuspciousmetadescription',
#  'crashoverride',
#  'wiperauthor',
#  'dragos',
#  'inc',
#  'sysbasconcom',
#  'fullword',
#  'nocase',
#  'pcmp',
#  'fullword',
#  'nocase',
#  'pcmi',
#  'fullword',
#  'nocase',
#  'pcmt',
#  'fullword',
#  'nocase',
#  'cin',
#  'fullword',
#  'nocase',
#  'wideconditionpeexportscrash',
#  'rule',
#  'dragoscrashoverridenamesearch',
#  'metadescription',
#  'crashoverride',
#  'suspicious',
#  'strings',
#  'exportauthor',
#  'dragos',
#  'inc',
#  'fullword',
#  'nocase',
#  'fullword',
#  'nocase',
#  'fullword',
#  'nocase',
#  'fullword',
#  'nocase',
#  'fullword',
#  'nocase',
#  'fullword',
#  'nocase',
#  'opcclientdemodll',
#  'fullword',
#  'nocase',
#  'opc',
#  'fullword',
#  'nocase',
#  'crashopcclientdemodll',
#  'fullword',
#  'nocase',
#  'fullword',
#  'nocase',
#  'fullword',
#  'nocase',
#  'fullword',
#  'nocase',
#  'opcexe',
#  'fullword',
#  'nocase',
#  'hasloexe',
#  'fullword',
#  'nocase',
#  'haslodat',
#  'fullword',
#  'nocase',
#  'wideconditionany',
#  'peexportscrash',
#  'rule',
#  'dragoscrashoverridehashes',
#  'metadescription',
#  'crashoverride',
#  'malware',
#  'hashesauthor',
#  'dragos',
#  'inc',
#  'conditionfilesize',
#  'filesize',
#  'filesize',
#  'filesize',
#  'filesize',
#  'filesize',
#  'filesize',
#  'filesize',
#  'filesize',
#  'filesize',
#  'rule',
#  'dragoscrashoverridemodulestrings',
#  'metadescription',
#  'interaction',
#  'module',
#  'program',
#  'stringsauthor',
#  'dragos',
#  'inc',
#  'client',
#  'ips',
#  'ports',
#  'asduu',
#  'nocase',
#  'wide',
#  'mstr',
#  'slv',
#  'nocase',
#  'wide',
#  'mstr',
#  'slv',
#  'nocase',
#  'wide',
#  'unknown',
#  'apdu',
#  'format',
#  'nocase',
#  'wide',
#  'nocase',
#  'wide',
#  'asciiconditionany',
#  'rule',
#  'dragoscrashoverrideconfigreadermetadescription',
#  'crashoverride',
#  'config',
#  'file',
#  'parsingauthor',
#  'dragos',
#  'inc',
#  'eb',
#  'cf',
#  'conditionall',
#  'rule',
#  'dragoscrashoverrideconfigreadermetadescription',
#  'crashoverride',
#  'config',
#  'file',
#  'parsingauthor',
#  'dragos',
#  'inc',
#  'eb',
#  'cf',
#  'conditionall',
#  'rule',
#  'dragoscrashoverrideweirdmutexmetadescription',
#  'blank',
#  'mutex',
#  'creation',
#  'assoicated',
#  'crashoverrideauthor',
#  'dragos',
#  'inc',
#  'ec',
#  'ff',
#  'ff',
#  'ff',
#  'ff',
#  'rule',
#  'dragoscrashoverrideservicestompermetadescription',
#  'identify',
#  'service',
#  'hollowing',
#  'persistence',
#  'settingauthor',
#  'dragos',
#  'inc',
#  'ff',
#  'ff',
#  'ff',
#  'ff',
#  'ff',
#  'ff',
#  'conditionall',
#  'rule',
#  'dragoscrashoverridewipermoduleregistrymetadescription',
#  'registry',
#  'wiper',
#  'functionality',
#  'assoicated',
#  'crashoverrideauthor',
#  'dragos',
#  'inc',
#  'ff',
#  'ff',
#  'ff',
#  'ff',
#  'conditionall',
#  'rule',
#  'dragoscrashoverridewiperfilemanipulationmetadescription',
#  'file',
#  'manipulation',
#  'actions',
#  'associated',
#  'crashoverride',
#  'wip¬erauthor',
#  'dragos',
#  'inc',
#  'ff',
#  'ff',
#  'conditionall',
#  'impact',
#  'successful',
#  'network',
#  'intrusion',
#  'severe',
#  'impacts',
#  'particularly',
#  'compromise',
#  'becomes',
#  'public',
#  'sensitive',
#  'information',
#  'exposed',
#  'possible',
#  'impacts',
#  'include',
#  'temporary',
#  'permanent',
#  'loss',
#  'sensitive',
#  'proprietary',
#  'informationdisruption',
#  'regular',
#  'operationsfinancial',
#  'losses',
#  'incurred',
#  'restore',
#  'systems',
#  'files',
#  'andpotential',
#  'harm',
#  'organizations',
#  'reputation',
#  'solution',
#  'properly',
#  'implemented',
#  'defensive',
#  'techniques',
#  'common',
#  'cyber',
#  'hygiene',
#  'practices',
#  'increase',
#  'complexity',
#  'barriers',
#  'adversaries',
#  'must',
#  'overcome',
#  'gain',
#  'unauthorized',
#  'access',
#  'critical',
#  'information',
#  'networks',
#  'systems',
#  'addition',
#  'detection',
#  'prevention',
#  'mechanisms',
#  'expose',
#  'malicious',
#  'network',
#  'activity',
#  'enabling',
#  'organizations',
#  'contain',
#  'respond',
#  'intrusions',
#  'rapidly',
#  'set',
#  'defensive',
#  'techniques',
#  'programs',
#  'completely',
#  'avert',
#  'attacks',
#  'however',
#  'layered',
#  'cybersecurity',
#  'defenses',
#  'aid',
#  'reducing',
#  'organizations',
#  'attack',
#  'surface',
#  'increase',
#  'likelihood',
#  'detection',
#  'layered',
#  'mitigation',
#  'approach',
#  'known',
#  'defenseindepthnccic',
#  'based',
#  'mitigations',
#  'recommendations',
#  'analysis',
#  'public',
#  'reporting',
#  'malware',
#  'provide',
#  'updates',
#  'information',
#  'becomes',
#  'availablecritical',
#  'infrastructure',
#  'companies',
#  'ensure',
#  'following',
#  'best',
#  'practices',
#  'outlined',
#  'seven',
#  'steps',
#  'effectively',
#  'defend',
#  'industrial',
#  'control',
#  'systems',
#  'document',
#  'produced',
#  'jointly',
#  'dhs',
#  'nsa',
#  'fbi',
#  'application',
#  'whitelisting',
#  'application',
#  'whitelisting',
#  'awl',
#  'detect',
#  'prevent',
#  'attempted',
#  'execution',
#  'malware',
#  'uploaded',
#  'adversaries',
#  'application',
#  'whitelisting',
#  'hardens',
#  'operating',
#  'systems',
#  'prevents',
#  'execution',
#  'unauthorized',
#  'software',
#  'static',
#  'nature',
#  'systems',
#  'database',
#  'servers',
#  'humanmachine',
#  'interface',
#  'hmi',
#  'computers',
#  'make',
#  'ideal',
#  'candidates',
#  'run',
#  'awl',
#  'nccic',
#  'encourages',
#  'operators',
#  'work',
#  'vendors',
#  'baseline',
#  'calibrate',
#  'awl',
#  'deploymentsoperators',
#  'may',
#  'choose',
#  'implement',
#  'directory',
#  'whitelisting',
#  'rather',
#  'trying',
#  'list',
#  'every',
#  'possible',
#  'permutation',
#  'applications',
#  'environment',
#  'operators',
#  'may',
#  'implement',
#  'application',
#  'application',
#  'directory',
#  'whitelisting',
#  'microsoft',
#  'software',
#  'restriction',
#  'policy',
#  'srp',
#  'applocker',
#  'similar',
#  'application',
#  'whitelisting',
#  'software',
#  'safe',
#  'defaults',
#  'allow',
#  'applications',
#  'run',
#  'programfiles',
#  'ics',
#  'software',
#  'folders',
#  'locations',
#  'disallowed',
#  'unless',
#  'exception',
#  'granted',
#  'manage',
#  'authentication',
#  'authorization',
#  'malware',
#  'exploits',
#  'lack',
#  'authentication',
#  'authorization',
#  'common',
#  'ics',
#  'protocols',
#  'issue',
#  'unauthorized',
#  'commands',
#  'field',
#  'devices',
#  'asset',
#  'ownersoperators',
#  'implement',
#  'authentication',
#  'authorization',
#  'protocols',
#  'ensure',
#  'field',
#  'devices',
#  'verify',
#  'authenticity',
#  'commands',
#  'actioned',
#  'instances',
#  'legacy',
#  'hardware',
#  'may',
#  'capable',
#  'implementing',
#  'protections',
#  'cases',
#  'asset',
#  'owners',
#  'either',
#  'leverage',
#  'ics',
#  'firewalls',
#  'stateful',
#  'inspection',
#  'authentication',
#  'commands',
#  'upgrade',
#  'control',
#  'field',
#  'devices',
#  'adversaries',
#  'increasingly',
#  'focused',
#  'gaining',
#  'control',
#  'legitimate',
#  'credentials',
#  'especially',
#  'associated',
#  'highly',
#  'privileged',
#  'accounts',
#  'compromising',
#  'credentials',
#  'allows',
#  'adversaries',
#  'masquerade',
#  'legitimate',
#  'users',
#  'leaving',
#  'less',
#  'evidence',
#  'compromise',
#  'traditional',
#  'attack',
#  'options',
#  'ie',
#  'exploiting',
#  'vulnerabilities',
#  'uploading',
#  'malware',
#  'reason',
#  'operators',
#  'implement',
#  'multifactor',
#  'authentication',
#  'possible',
#  'reduce',
#  'privileges',
#  'needed',
#  'users',
#  'duties',
#  'passwords',
#  'necessary',
#  'operators',
#  'implement',
#  'secure',
#  'password',
#  'policies',
#  'stressing',
#  'length',
#  'complexity',
#  'accounts',
#  'including',
#  'system',
#  'noninteractive',
#  'accounts',
#  'operators',
#  'ensure',
#  'credentials',
#  'unique',
#  'changed',
#  'minimum',
#  'every',
#  'days',
#  'nccic',
#  'also',
#  'recommends',
#  'operators',
#  'require',
#  'separate',
#  'credentials',
#  'corporate',
#  'control',
#  'network',
#  'zones',
#  'store',
#  'separate',
#  'trust',
#  'stores',
#  'operators',
#  'never',
#  'share',
#  'active',
#  'directory',
#  'rsa',
#  'ace',
#  'servers',
#  'trust',
#  'stores',
#  'corporate',
#  'control',
#  'networks',
#  'specifically',
#  'operators',
#  'decrease',
#  'threat',
#  'actors',
#  'ability',
#  'access',
#  'key',
#  'network',
#  'resources',
#  'implementing',
#  'principle',
#  'least',
#  'privilegelimit',
#  'ability',
#  'local',
#  'administrator',
#  'account',
#  'login',
#  'local',
#  'interactive',
#  'session',
#  'eg',
#  'deny',
#  'access',
#  'computer',
#  'network',
#  'prevent',
#  'access',
#  'via',
#  'remote',
#  'desktop',
#  'protocol',
#  'sessionremove',
#  'unnecessary',
#  'accounts',
#  'groups',
#  'restrict',
#  'root',
#  'accesscontrol',
#  'limit',
#  'local',
#  'administration',
#  'andmake',
#  'use',
#  'protected',
#  'users',
#  'active',
#  'directory',
#  'group',
#  'windows',
#  'domains',
#  'secure',
#  'privileged',
#  'user',
#  'accounts',
#  'passthehash',
#  'attacks',
#  'handling',
#  'destructive',
#  'malware',
#  'destructive',
#  'malware',
#  'continues',
#  'threat',
#  'critical',
#  'infrastructure',
#  'business',
#  'systems',
#  'nccic',
#  'encourages',
#  'organizations',
#  'review',
#  'icscert',
#  'destructive',
#  'malware',
#  'white',
#  'paper',
#  'detailed',
#  'mitigation',
#  'guidance',
#  'important',
#  'organizations',
#  'maintain',
#  'backups',
#  'key',
#  'data',
#  'systems',
#  'configurations',
#  'server',
#  'gold',
#  'imagesics',
#  'workstation',
#  'gold',
#  'configurationsengineering',
#  'workstation',
#  'imagesplcrtu',
#  'configurationspasswords',
#  'configuration',
#  'information',
#  'andoffline',
#  'copies',
#  ...]

# %%
from collection import Counter

top = [word for ]

# %%
#Part of Speech (POS) Tagging
#POS tag list:
'''
CC	coordinating conjunction
CD	cardinal digit
DT	determiner
EX	existential there (like: "there is" ... think of it like "there exists")
FW	foreign word
IN	preposition/subordinating conjunction
JJ	adjective	'big'
JJR	adjective, comparative	'bigger'
JJS	adjective, superlative	'biggest'
LS	list marker	1)
MD	modal	could, will
NN	noun, singular 'desk'
NNS	noun plural	'desks'
NNP	proper noun, singular	'Harrison'
NNPS	proper noun, plural	'Americans'
PDT	predeterminer	'all the kids'
POS	possessive ending	parent\'s
PRP	personal pronoun	I, he, she
PRP$	possessive pronoun	my, his, hers
RB	adverb	very, silently,
RBR	adverb, comparative	better
RBS	adverb, superlative	best
RP	particle	give up
TO	to	go 'to' the store.
UH	interjection	errrrrrrrm
VB	verb, base form	take
VBD	verb, past tense	took
VBG	verb, gerund/present participle	taking
VBN	verb, past participle	taken
VBP	verb, sing. present, non-3d	take
VBZ	verb, 3rd person sing. present	takes
WDT	wh-determiner	which
WP	wh-pronoun	who, what
WP$	possessive wh-pronoun	whose
WRB	wh-abverb	where, when
'''
tagged = nltk.pos_tag(filtered)
print(tagged)
# Out:
# [('alert', 'JJ'), ('crashoverride', 'NN'), ('malware', 'NN'), ('systems', 'NNS'), ('affected', 'VBD'), ('industrial', 'JJ'), ('control', 'NN'), ('systems', 'NNS'), ('overview', 'VBP'), ('national', 'JJ'), ('cybersecurity', 'NN'), ('communications', 'NNS'), ('integration', 'NN'), ('center', 'NN'), ('nccic', 'NN'), ('aware', 'JJ'), ('public', 'JJ'), ('reports', 'NNS'), ('eset', 'VBD'), ('dragos', 'NNS'), ('outlining', 'VBG'), ('new', 'JJ'), ('highly', 'RB'), ('capable', 'JJ'), ('industrial', 'JJ'), ('controls', 'NNS'), ('systems', 'NNS'), ('ics', 'NNS'), ('attack', 'VBP'), ('platform', 'NN'), ('reportedly', 'RB'), ('used', 'VBD'), ('critical', 'JJ'), ('infrastructure', 'NN'), ('ukraine', 'NN'), ('reported', 'VBD'), ('eset', 'JJ'), ('dragos', 'NNS'), ('crashoverride', 'VBP'), ('malware', 'NN'), ('extensible', 'JJ'), ('platform', 'NN'), ('could', 'MD'), ('used', 'VBN'), ('target', 'VB'), ('critical', 'JJ'), ('infrastructure', 'NN'), ('sectors', 'NNS'), ('nccic', 'VBP'), ('working', 'VBG'), ('partners', 'NNS'), ('validate', 'JJ'), ('eset', 'VBN'), ('dragos', 'JJ'), ('analysis', 'NN'), ('develop', 'VB'), ('better', 'RBR'), ('understanding', 'VBG'), ('risk', 'NN'), ('new', 'JJ'), ('malware', 'NN'), ('poses', 'VBZ'), ('us', 'PRP'), ('critical', 'JJ'), ('infrastructure', 'NN'), ('although', 'IN'), ('activity', 'NN'), ('still', 'RB'), ('investigation', 'NN'), ('nccic', 'IN'), ('sharing', 'VBG'), ('report', 'NN'), ('provide', 'VBP'), ('organizations', 'NNS'), ('detection', 'NN'), ('mitigation', 'NN'), ('recommendations', 'NNS'), ('help', 'VBP'), ('prevent', 'VB'), ('future', 'JJ'), ('compromises', 'NNS'), ('within', 'IN'), ('critical', 'JJ'), ('infrastructure', 'NN'), ('networks', 'NNS'), ('nccic', 'VBP'), ('continues', 'VBZ'), ('work', 'NN'), ('interagency', 'NN'), ('international', 'JJ'), ('partners', 'NNS'), ('activity', 'NN'), ('provide', 'VBP'), ('updates', 'VBZ'), ('information', 'NN'), ('becomes', 'VBZ'), ('available', 'JJ'), ('downloadable', 'JJ'), ('copy', 'NN'), ('indicators', 'NNS'), ('compromise', 'VBP'), ('iocs', 'JJ'), ('see', 'VBP'), ('iocs', 'JJ'), ('csviocs', 'NNS'), ('stix', 'JJ'), ('report', 'NN'), ('activity', 'NN'), ('related', 'VBN'), ('alert', 'JJ'), ('please', 'NN'), ('contact', 'NN'), ('nccic', 'JJ'), ('ncciccustomerservicehqdhsgov', 'NN'), ('risk', 'NN'), ('evaluation', 'NN'), ('nccic', 'IN'), ('cyber', 'JJ'), ('incident', 'NN'), ('scoring', 'VBG'), ('system', 'NN'), ('nciss', 'JJ'), ('rating', 'NN'), ('priority', 'NN'), ('level', 'NN'), ('coloryellow', 'NN'), ('mediuma', 'NN'), ('medium', 'NN'), ('priority', 'NN'), ('incident', 'NN'), ('may', 'MD'), ('affect', 'VB'), ('public', 'JJ'), ('health', 'NN'), ('safety', 'NN'), ('national', 'JJ'), ('security', 'NN'), ('economic', 'JJ'), ('security', 'NN'), ('foreign', 'JJ'), ('relations', 'NNS'), ('civil', 'JJ'), ('liberties', 'NNS'), ('public', 'JJ'), ('confidence', 'NN'), ('details', 'NNS'), ('evidence', 'NN'), ('suggest', 'VBP'), ('malware', 'NN'), ('affected', 'VBD'), ('us', 'PRP'), ('critical', 'JJ'), ('infrastructure', 'NN'), ('however', 'RB'), ('tactics', 'NNS'), ('techniques', 'NNS'), ('procedures', 'NNS'), ('ttps', 'VBP'), ('described', 'VBN'), ('part', 'NN'), ('crashoverride', 'NN'), ('malware', 'NN'), ('could', 'MD'), ('modified', 'VB'), ('target', 'VB'), ('us', 'PRP'), ('critical', 'JJ'), ('information', 'NN'), ('networks', 'NNS'), ('systems', 'NNS'), ('description', 'NN'), ('technical', 'JJ'), ('analysis', 'NN'), ('crashoverride', 'NN'), ('malware', 'NN'), ('represents', 'VBZ'), ('scalable', 'JJ'), ('capable', 'JJ'), ('platform', 'NN'), ('modules', 'NNS'), ('capabilities', 'NNS'), ('publically', 'RB'), ('reported', 'VBD'), ('appear', 'JJ'), ('focus', 'NN'), ('organizations', 'NNS'), ('using', 'VBG'), ('ics', 'NNS'), ('protocols', 'NNS'), ('commonly', 'RB'), ('used', 'VBD'), ('outside', 'JJ'), ('united', 'JJ'), ('states', 'NNS'), ('electric', 'JJ'), ('power', 'NN'), ('control', 'NN'), ('systems', 'NNS'), ('platform', 'VBP'), ('fundamentally', 'RB'), ('abuse ...

# %%
namedEnt = nltk.ne_chunk(tagged, binary=True)
namedEnt.draw()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-9d5e87411ac1> in <module>
#       1 namedEnt = nltk.ne_chunk(tagged, binary=True)
# ----> 2 namedEnt.draw()
#
# /anaconda3/lib/python3.7/site-packages/nltk/tree.py in draw(self)
#     744         from nltk.draw.tree import draw_trees
#     745
# --> 746         draw_trees(self)
#     747
#     748     def pretty_print(self, sentence=None, highlight=(), stream=None, **kwargs):
#
# /anaconda3/lib/python3.7/site-packages/nltk/draw/tree.py in draw_trees(*trees)
#    1006     :rtype: None
#    1007     """
# -> 1008     TreeView(*trees).mainloop()
#    1009     return
#    1010
#
# /anaconda3/lib/python3.7/site-packages/nltk/draw/tree.py in __init__(self, *trees)
#     885                 line_color='#004040',
#     886                 draggable=1,
# --> 887                 leaf_font=helv,
#     888             )
#     889             widget.bind_click_trees(widget.toggle_collapsed)
#
# /anaconda3/lib/python3.7/site-packages/nltk/draw/tree.py in __init__(self, canvas, t, make_node, make_leaf, **attribs)
#     581         self._add_child_widget(self._treeseg)
#     582
# --> 583         CanvasWidget.__init__(self, canvas, **attribs)
#     584
#     585     def expanded_tree(self, *path_to_tree):
#
# /anaconda3/lib/python3.7/site-packages/nltk/draw/util.py in __init__(self, canvas, parent, **attribs)
#     221
#     222         # Manage this canvas widget
# --> 223         self._manage()
#     224
#     225         # Register any new bindings
#
# /anaconda3/lib/python3.7/site-packages/nltk/draw/tree.py in _manage(self)
#     811             if tseg.hidden():
#     812                 tseg.show()
# --> 813                 tseg.manage()
#     814                 tseg.hide()
#     815
#
# /anaconda3/lib/python3.7/site-packages/nltk/draw/util.py in manage(self)
#     411         for child in self.__children:
#     412             child.manage()
# --> 413         self._manage()
#     414
#     415     def tags(self):
#
# /anaconda3/lib/python3.7/site-packages/nltk/draw/tree.py in _manage(self)
#     412         # Update lines to subtrees.
#     413         for subtree in self._subtrees:
# --> 414             self._update(subtree)
#     415
#     416         self._managing = False
#
# /anaconda3/lib/python3.7/site-packages/nltk/draw/tree.py in _update(self, child)
#     244         (xmin, ymin, xmax, ymax) = self._subtrees[0].bbox()
#     245         for subtree in self._subtrees[1:]:
# --> 246             bbox = subtree.bbox()
#     247             xmin = min(xmin, bbox[0])
#     248             ymin = min(ymin, bbox[1])
#
# /anaconda3/lib/python3.7/site-packages/nltk/draw/util.py in bbox(self)
#     246         if len(self.tags()) == 0:
#     247             raise ValueError('No tags')
# --> 248         return self.__canvas.bbox(*self.tags())
#     249
#     250     def width(self):
#
# /anaconda3/lib/python3.7/tkinter/__init__.py in bbox(self, *args)
#    2437         which encloses all items with tags specified as arguments."""
#    2438         return self._getints(
# -> 2439             self.tk.call((self._w, 'bbox') + args)) or None
#    2440     def tag_unbind(self, tagOrId, sequence, funcid=None):
#    2441         """Unbind for all items with TAGORID for event SEQUENCE  the
#
# KeyboardInterrupt:
